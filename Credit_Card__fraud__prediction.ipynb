# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
#Loading gthe datset into a Pandas Dataframe
cc=pd.read_csv('/content/creditcard.csv')
cc.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
cc.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 41678  40781 -0.447381  1.134089  0.534095 -0.192366  1.344408 -0.370402
# 41679  40782  1.133168  0.406826  0.956032  2.315761 -0.242409  0.225013
# 41680  40783 -0.536190  1.355132  0.064049  0.884589  0.581654 -0.179437
# 41681  40783 -0.498757  0.332449  1.917148 -2.340131 -1.098398 -0.863136
# 41682  40784 -0.621229 -0.733600       NaN       NaN       NaN       NaN
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 41678  1.088646 -0.094025 -0.444502  ... -0.050234 -0.092340 -0.463501
# 41679 -0.295703  0.130832 -0.768433  ...  0.180411  0.487918 -0.121882
# 41680  0.466058  0.213312 -0.130088  ... -0.013520  0.198903 -0.112066
# 41681 -0.055820 -0.084046  1.673677  ...  0.371752  1.441352 -0.250882
# 41682       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41683 entries, 0 to 41682
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    41683 non-null  int64
#  1   V1      41683 non-null  float64
#  2   V2      41683 non-null  float64
#  3   V3      41682 non-null  float64
#  4   V4      41682 non-null  float64
#  5   V5      41682 non-null  float64
#  6   V6      41682 non-null  float64
#  7   V7      41682 non-null  float64
#  8   V8      41682 non-null  float64
#  9   V9      41682 non-null  float64
#  10  V10     41682 non-null  float64
#  11  V11     41682 non-null  float64
#  12  V12     41682 non-null  float64
#  13  V13     41682 non-null  float64
#  14  V14     41682 non-null  float64
#  15  V15     41682 non-null  float64
#  16  V16     41682 non-null  float64
#  17  V17     41682 non-null  float64
#  18  V18     41682 non-null  float64
#  19  V19     41682 non-null  float64
# ...

# %%
cc.shape
# Out:
# (41683, 31)

# %%
cc.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        1
# V4        1
# V5        1
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
#cleaning one row of missing value in amount and class columns presented 1 Missing row

cc.dropna(inplace=True)

# %%
cc['Class'].value_counts()
# Out:
# Class
# 0.0    41574
# 1.0      108
# Name: count, dtype: int64

# %% [markdown]
# **Here from Dataset seen that there is unbalanced data between two variables**

# %%
#Establish 2 variables i.e Fraud and Non_fraud represented by 1 and 0 respectively

non_fraud=cc[cc.Class==0]
fraud=cc[cc.Class==1]

# %%
a=len(cc[cc.Class==0])
b=len(cc[cc.Class==1])

# %%
print('Non Fraud size :',non_fraud.shape)
print('Fraud size :',fraud.shape)
# Out:
# Non Fraud size : (41574, 31)
# Fraud size : (108, 31)

# %%
fraud_percent= (b/(a+b))*100
fraud_percent
# Out:
# 0.25910464948898804

# %%
#statistical info for both the varaibles i.e non_fraud and fraud
non_fraud.Amount.describe()
# Out:
# count    41574.000000
# mean        89.092554
# std        237.129967
# min          0.000000
# 25%          7.550000
# 50%         24.000000
# 75%         80.000000
# max       7879.420000
# Name: Amount, dtype: float64

# %%
fraud['Amount'].describe()
# Out:
# count     108.000000
# mean       93.512593
# std       250.863273
# min         0.000000
# 25%         1.000000
# 50%         2.320000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
#Comparing both the transactions i.e for 1 and 0

cc.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    26220.447082 -0.203702  0.021029   0.74135  0.172070 -0.222039
# 1.0    21414.990741 -7.454643  5.595067 -10.62406  5.849772 -5.115950
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.105713 -0.093360  0.035106  0.201757  ...  0.045420 -0.030057
# 1.0   -2.288288 -7.382457  3.691487 -2.904887  ...  0.630658  0.602725
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.110755 -0.039591  0.007931  0.135806  0.022783  0.005968  0.004583
# 1.0   -0.336878 -0.313708 -0.237598  0.310378  0.183470  0.791559  0.112874
#
#           Amount
# Class
# 0.0    89.092554
# 1.0    93.512593
#
# [2 rows x 30 columns]

# %% [markdown]
# Under-Sampling
# Build a sample dataset containing similar distribution of normal transactions and Fraudulent Transactions
# Number of Fraudulent Transactions -> 108

# %%
non_fraud_sample=non_fraud.sample(n=108)

# %% [markdown]
# Concatenating two Dataframes

# %%
new_dataset=pd.concat([non_fraud_sample,fraud],axis=0)

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 12065  20924  1.165030 -0.474963  0.868046 -0.742740 -0.860283  0.177173
# 19604  30405 -0.955540  0.678570  2.847705 -0.120814 -0.956849 -0.085584
# 20090  30778 -1.319084  0.007887 -0.529591 -0.100765  2.114656  3.869385
# 37750  39087  1.151937 -0.629484  0.448802  0.218026 -0.740691  0.233123
# 24007  33020 -1.260891  0.493450  3.210962  1.974398 -0.812824  0.420278
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 12065 -0.929069  0.265808  3.065808  ... -0.113846  0.079664 -0.040995
# 19604 -0.280493  0.405250  0.143967  ...  0.291078  0.788804 -0.287220
# 20090  1.313731  0.566197 -1.042173  ... -0.061558 -0.236345 -0.272068
# 37750 -0.602123  0.039490 -1.045297  ... -0.139528 -0.081162 -0.224926
# 24007  1.057627 -0.471994 -0.494244  ...  0.140617  0.904071 -0.437278
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset['Class'].value_counts()   # here we changed the unbalanced data into balanced
# Out:
# Class
# 0.0    108
# 1.0    108
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    30131.842593 -0.208046 -0.125558   0.703219  0.321395 -0.306557
# 1.0    21414.990741 -7.454643  5.595067 -10.624060  5.849772 -5.115950
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.263424 -0.106156  0.055751 -0.163198  ...  0.014365 -0.078758
# 1.0   -2.288288 -7.382457  3.691487 -2.904887  ...  0.630658  0.602725
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.110649 -0.137869  0.025896  0.115924 -0.148159 -0.001239  0.047535
# 1.0   -0.336878 -0.313708 -0.237598  0.310378  0.183470  0.791559  0.112874
#
#            Amount
# Class
# 0.0    115.115926
# 1.0     93.512593
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting the data into features and target

# %%
X=new_dataset.drop(columns='Class',axis=1)
Y=new_dataset['Class']

# %%
print(X.shape)
print(Y.shape)
# Out:
# (216, 30)
# (216,)

# %% [markdown]
# Split the data into training and testing Data

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (216, 30) (172, 30) (44, 30)

# %% [markdown]
# **Model Training : Logistic Regression**

# %%
model =LogisticRegression()

# %%
#training the model with training data
model.fit (X_train,Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
cal_score=model.score(X_test,Y_test)*100
cal_score
# Out:
# 95.45454545454545

# %%
from sklearn.preprocessing import StandardScaler  #to get normalized by defaulty
scaler=StandardScaler()

# %%
cc['normalized_amount']=scaler.fit_transform(cc['Amount'].values.reshape(-1,1))  #to adjust the value in amount column between high difference

# %%
cc.drop(['Amount','Time'],inplace=True,axis=1)

# %%
cc.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Class  normalized_amount
# ...

# %%
#dividing the dataset into dependent and independent variables x&y

x=cc.drop(['Class'],axis=1)

# %%
y=cc['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split (x,y,test_size=0.3,random_state=1)

# %%
x_test.shape
# Out:
# (4186, 29)

# %%
x_train.shape
# Out:
# (9767, 29)

# %%
#create a model
from sklearn.ensemble import RandomForestClassifier
rf1=RandomForestClassifier(n_estimators=100)  #setting up the number of tress  i.e 100 given

# %%
rf1.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
prediction_cal=rf1.predict(x_test)

# %%
cal_score=rf1.score(x_test,y_test)*100
cal_score
# Out:
# 99.88055422838032
